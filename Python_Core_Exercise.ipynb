# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0553-2nd/NASSCOM-LAB/blob/main/Python_Core_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")
# Task 1.1

raw_sensor_data = []

for i in range(100):

    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    minimum, maximum = READING_RANGES[device_type]
    value = round(random.uniform(minimum, maximum), 2)

    reading = (timestamp, device_id, device_type, location, value)

    raw_sensor_data.append(reading)

for reading in raw_sensor_data[:5]:
    print(reading)














    #task 1.2

temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        })

#task 1.3

print(temperature_readings[:5])

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print(unique_locations)

#task 1.4

device_stats = {}

# Initialize
for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

# Update min and max
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device_type]

    if value < current_min:
        current_min = value

    if value > current_max:
        current_max = value

    device_stats[device_type] = (current_min, current_max)

print(device_stats)

#task 1.5.1

sliced_readings_1 = raw_sensor_data[9:20]

print(sliced_readings_1)

sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_2)

#task 1.5.2

sample_string = "PythonProgrammingIsFun"

substring_1 = sample_string[6:17]

print(substring_1)

substring_2 = sample_string[5::-1]

print(substring_2)

#task 1.5.3

fifth_reading_device_type = raw_sensor_data[4][2]

print(fifth_reading_device_type)

device_type_suffix = fifth_reading_device_type[-6:]

print(device_type_suffix)

#task 2.1

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")


first_timestamp = datetime.datetime.strptime(raw_sensor_data[0][0], "%Y-%m-%d %H:%M:%S")
last_timestamp = datetime.datetime.strptime(raw_sensor_data[-1][0], "%Y-%m-%d %H:%M:%S")

duration = last_timestamp - first_timestamp

days = duration.days
hours = duration.seconds // 3600
minutes = (duration.seconds % 3600) // 60

print(f"Duration: {days} days, {hours} hours, {minutes} minutes")


random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print(random_values)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-19 15:42:41', 'DEV001', 'Pressure_Sensor', 'Lab2', 985.66)
# ('2026-07-19 15:42:41', 'DEV002', 'Light_Sensor', 'OfficeB', 341.08)
# ('2026-07-19 15:42:41', 'DEV003', 'Pressure_Sensor', 'Lab1', 1002.16)
# ('2026-07-19 15:42:41', 'DEV004', 'Temperature_Sensor', 'Warehouse', 27.67)
# ('2026-07-19 15:42:41', 'DEV005', 'Pressure_Sensor', 'Lab1', 987.59)
# [{'timestamp': '2026-07-19 15:42:41', 'device_id': 'DEV004', 'location': 'Warehouse', 'temperature_celsius': 27.67}, {'timestamp': '2026-07-19 15:42:41', 'device_id': 'DEV007', 'location': 'OfficeB', 'temperature_celsius': 20.6}, {'timestamp': '2026-07-19 15:42:41', 'device_id': 'DEV009', 'location': 'OfficeA', 'temperature_celsius': 19.99}, {'timestamp': '2026-07-19 15:42:41', 'device_id': 'DEV014', 'location': 'OfficeA', 'temperature_celsius': 18.26}, {'timestamp': '2026-07-19 15:42:41', 'device_id': 'DEV019', 'location': 'Lab2', 'temperature_celsius': 23.75}]
# {'OfficeA', 'Lab1', 'Lab2', 'Warehouse', 'OfficeB'}
# {'Temperature_Sensor': (18.02, 27.67), 'Humidity_Sensor': (30.76, 75.94), 'Pressure_Sensor': (981.28, 1029.09), 'Light_Sensor': (198.13, 969.62)}
# [('2026-07-19 15:42:41', 'DEV010', 'Humidity_Sensor', 'Warehouse', 50.58), ('2026-07-19 15:42:41', 'DEV011', 'Light_Sensor', 'OfficeA', 467.47), ('2026-07-19 15:42:41', 'DEV012', 'Humidity_Sensor', 'Lab1', 35.42), ('2026-07-19 15:42:41', 'DEV013', 'Humidity_Sensor', 'Lab1', 36.65), ('2026-07-19 15:42:41', 'DEV014', 'Temperature_Sensor', 'OfficeA', 18.26), ('2026-07-19 15:42:41', 'DEV015', 'Pressure_Sensor', 'OfficeA', 1016.41), ('2026-07-19 15:42:41', 'DEV016', 'Light_Sensor', 'Warehouse', 528.27), ('2026-07-19 15:42:41', 'DEV017', 'Light_Sensor', 'Lab1', 198.13), ('2026-07-19 15:42:41', 'DEV018', 'Pressure_Sensor', 'Lab2', 988.48), ('2026-07-19 15:42:41', 'DEV019', 'Temperature_Sensor', 'Lab2', 23.75), ('2026-07-19 15:42:41', 'DEV020', 'Light_Sensor', 'OfficeA', 945.42)]
# [('2026-07-19 15:42:41', 'DEV001', 'Pressure_Sensor', 'Lab2', 985.66), ('2026-07-19 15:42:41', 'DEV006', 'Light_Sensor', 'OfficeA', 425.0), ('2026-07-19 15:42:41', 'DEV011', 'Light_Sensor', 'OfficeA', 467.47), ('2026-07-19 15:42:41', 'DEV016', 'Light_Sensor', 'Warehouse', 528.27), ('2026-07-19 15:42:41', 'DEV021', 'Light_Sensor', 'OfficeB', 511.43), ('2026-07-19 15:42:41', 'DEV026', 'Temperature_Sensor', 'OfficeB', 25.18), ('2026-07-19 15:42:41', 'DEV031', 'Humidity_Sensor', 'Lab2', 31.28), ('2026-07-19 15:42:41', 'DEV036', 'Temperature_Sensor', 'Lab2', 26.34), ('2026-07-19 15:42:41', 'DEV041', 'Pressure_Sensor', 'Lab2', 1004.97), ('2026-07-19 15:42:41', 'DEV046', 'Humidity_Sensor', 'Lab2', 49.11), ('2026-07-19 15:42:41', 'DEV051', 'Light_Sensor', 'Lab1', 806.05), ('2026-07-19 15:42:41', 'DEV056', 'Pressure_Sensor', 'Warehouse', 1001.68), ('2026-07-19 15:42:41', 'DEV061', 'Light_Sensor', 'Lab1', 238.83), ('2026-07-19 15:42:41', 'DEV066', 'Temperature_Sensor', 'Warehouse', 22.23), ('2026-07-19 15:42:41', 'DEV071', 'Pressure_Sensor', 'Lab1', 1001.43), ('2026-07-19 15:42:41', 'DEV076', 'Pressure_Sensor', 'Lab1', 1027.42), ('2026-07-19 15:42:41', 'DEV081', 'Humidity_Sensor', 'Warehouse', 61.69), ('2026-07-19 15:42:41', 'DEV086', 'Humidity_Sensor', 'Lab2', 63.66), ('2026-07-19 15:42:41', 'DEV091', 'Humidity_Sensor', 'Warehouse', 35.42), ('2026-07-19 15:42:41', 'DEV096', 'Pressure_Sensor', 'OfficeB', 1022.0)]
# Programming
# nohtyP
# Pressure_Sensor
# Sensor
# Directory 'sensor_reports' created.
# Duration: 0 days, 0 hours, 0 minutes
# [199, 177, 189, 135, 150]
