# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0553-2nd/NASSCOM-LAB/blob/main/Python_Core_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")
# Task 1.1

raw_sensor_data = []

for i in range(100):

    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    minimum, maximum = READING_RANGES[device_type]
    value = round(random.uniform(minimum, maximum), 2)

    reading = (timestamp, device_id, device_type, location, value)

    raw_sensor_data.append(reading)

for reading in raw_sensor_data[:5]:
    print(reading)














    #task 1.2

temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        })

#task 1.3

print(temperature_readings[:5])

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print(unique_locations)

#task 1.4

device_stats = {}

# Initialize
for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

# Update min and max
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device_type]

    if value < current_min:
        current_min = value

    if value > current_max:
        current_max = value

    device_stats[device_type] = (current_min, current_max)

print(device_stats)

#task 1.5.1

sliced_readings_1 = raw_sensor_data[9:20]

print(sliced_readings_1)

sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_2)

#task 1.5.2

sample_string = "PythonProgrammingIsFun"

substring_1 = sample_string[6:17]

print(substring_1)

substring_2 = sample_string[5::-1]

print(substring_2)

#task 1.5.3

fifth_reading_device_type = raw_sensor_data[4][2]

print(fifth_reading_device_type)

device_type_suffix = fifth_reading_device_type[-6:]

print(device_type_suffix)

#task 2.1

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")


first_timestamp = datetime.datetime.strptime(raw_sensor_data[0][0], "%Y-%m-%d %H:%M:%S")
last_timestamp = datetime.datetime.strptime(raw_sensor_data[-1][0], "%Y-%m-%d %H:%M:%S")

duration = last_timestamp - first_timestamp

days = duration.days
hours = duration.seconds // 3600
minutes = (duration.seconds % 3600) // 60

print(f"Duration: {days} days, {hours} hours, {minutes} minutes")


random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print(random_values)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-19 15:45:07', 'DEV001', 'Temperature_Sensor', 'Lab2', 18.47)
# ('2026-07-19 15:45:07', 'DEV002', 'Humidity_Sensor', 'OfficeB', 72.25)
# ('2026-07-19 15:45:07', 'DEV003', 'Pressure_Sensor', 'OfficeB', 1007.37)
# ('2026-07-19 15:45:07', 'DEV004', 'Pressure_Sensor', 'OfficeA', 999.79)
# ('2026-07-19 15:45:07', 'DEV005', 'Light_Sensor', 'OfficeB', 935.54)
# [{'timestamp': '2026-07-19 15:45:07', 'device_id': 'DEV001', 'location': 'Lab2', 'temperature_celsius': 18.47}, {'timestamp': '2026-07-19 15:45:07', 'device_id': 'DEV008', 'location': 'Lab1', 'temperature_celsius': 19.07}, {'timestamp': '2026-07-19 15:45:07', 'device_id': 'DEV011', 'location': 'Lab2', 'temperature_celsius': 21.89}, {'timestamp': '2026-07-19 15:45:07', 'device_id': 'DEV013', 'location': 'OfficeA', 'temperature_celsius': 18.46}, {'timestamp': '2026-07-19 15:45:07', 'device_id': 'DEV015', 'location': 'Warehouse', 'temperature_celsius': 19.4}]
# {'Lab1', 'Lab2', 'Warehouse', 'OfficeB', 'OfficeA'}
# {'Temperature_Sensor': (18.42, 29.78), 'Humidity_Sensor': (30.03, 79.83), 'Pressure_Sensor': (981.62, 1025.78), 'Light_Sensor': (184.33, 982.12)}
# [('2026-07-19 15:45:07', 'DEV010', 'Pressure_Sensor', 'OfficeB', 990.91), ('2026-07-19 15:45:07', 'DEV011', 'Temperature_Sensor', 'Lab2', 21.89), ('2026-07-19 15:45:07', 'DEV012', 'Light_Sensor', 'OfficeA', 508.88), ('2026-07-19 15:45:07', 'DEV013', 'Temperature_Sensor', 'OfficeA', 18.46), ('2026-07-19 15:45:07', 'DEV014', 'Pressure_Sensor', 'Lab1', 993.83), ('2026-07-19 15:45:07', 'DEV015', 'Temperature_Sensor', 'Warehouse', 19.4), ('2026-07-19 15:45:07', 'DEV016', 'Light_Sensor', 'Lab2', 209.5), ('2026-07-19 15:45:07', 'DEV017', 'Light_Sensor', 'Warehouse', 239.16), ('2026-07-19 15:45:07', 'DEV018', 'Light_Sensor', 'Warehouse', 331.46), ('2026-07-19 15:45:07', 'DEV019', 'Pressure_Sensor', 'OfficeB', 994.29), ('2026-07-19 15:45:07', 'DEV020', 'Pressure_Sensor', 'OfficeB', 1001.71)]
# [('2026-07-19 15:45:07', 'DEV001', 'Temperature_Sensor', 'Lab2', 18.47), ('2026-07-19 15:45:07', 'DEV006', 'Humidity_Sensor', 'OfficeB', 36.89), ('2026-07-19 15:45:07', 'DEV011', 'Temperature_Sensor', 'Lab2', 21.89), ('2026-07-19 15:45:07', 'DEV016', 'Light_Sensor', 'Lab2', 209.5), ('2026-07-19 15:45:07', 'DEV021', 'Humidity_Sensor', 'Lab2', 52.1), ('2026-07-19 15:45:07', 'DEV026', 'Temperature_Sensor', 'Warehouse', 24.69), ('2026-07-19 15:45:07', 'DEV031', 'Temperature_Sensor', 'Warehouse', 21.94), ('2026-07-19 15:45:07', 'DEV036', 'Humidity_Sensor', 'Warehouse', 60.99), ('2026-07-19 15:45:07', 'DEV041', 'Light_Sensor', 'Warehouse', 213.64), ('2026-07-19 15:45:07', 'DEV046', 'Pressure_Sensor', 'OfficeB', 981.62), ('2026-07-19 15:45:07', 'DEV051', 'Pressure_Sensor', 'OfficeB', 1022.26), ('2026-07-19 15:45:07', 'DEV056', 'Humidity_Sensor', 'OfficeB', 78.46), ('2026-07-19 15:45:07', 'DEV061', 'Temperature_Sensor', 'Warehouse', 20.69), ('2026-07-19 15:45:07', 'DEV066', 'Temperature_Sensor', 'Lab2', 25.17), ('2026-07-19 15:45:07', 'DEV071', 'Pressure_Sensor', 'Lab1', 1021.32), ('2026-07-19 15:45:07', 'DEV076', 'Pressure_Sensor', 'Lab2', 1007.18), ('2026-07-19 15:45:07', 'DEV081', 'Pressure_Sensor', 'Lab1', 1018.25), ('2026-07-19 15:45:07', 'DEV086', 'Pressure_Sensor', 'Lab2', 987.5), ('2026-07-19 15:45:07', 'DEV091', 'Temperature_Sensor', 'OfficeA', 29.78), ('2026-07-19 15:45:07', 'DEV096', 'Humidity_Sensor', 'OfficeA', 56.68)]
# Programming
# nohtyP
# Light_Sensor
# Sensor
# Directory 'sensor_reports' created.
# Duration: 0 days, 0 hours, 0 minutes
# [150, 110, 160, 106, 159]
